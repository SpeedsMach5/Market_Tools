# %%
import streamlit as st
from datetime import date
import yfinance as yf
from fbprophet import Prophet
from fbprophet.plot import plot_plotly
from plotly import graph_objs as go
import numpy as np
# Out:
# 1.20.1

# %%
#date range

START = "2010-01-01"
TODAY = date.today().strftime("%Y-%m-%d")
#title
st.title("Just 2 Traders predictions")
#stocks
stocks = ("AAPL","GOOG", "MSFT")
selected_stock = st.selectbox("Stocks to hunt",stocks)
#time analysis
n_years = st.slider("Time", 1, 4)
period = n_years * 7

# %%
#data function

#@st.cache
def load_data(ticker):
    data = yf.download(ticker,START,TODAY)
    data.reset_index(inplace=True)
    return data

#data output
data_load_state = st.text("Hunting the market")
data = load_data(selected_stock)
data_load_state.text("Finished hunting")
# Out:
# [*********************100%***********************]  1 of 1 completed
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
#subheader
st.subheader("Raw meat")
st.write(data.tail())

#plot function
def plot_raw_meat_data():
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=data["Date"], y=date["Open"], name = "Stock open"))
    fig.add_trace(go.Scatter(x=data["Date"], y=date["Close"], name = "Stock close"))
    fig.layout.update(title_text="Time analysis", xaxis_rangeslider_visible=True)
    st.plotly_chart(fig)
plot_raw_meat_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ab2b83e2d040> in <module>
#      10     fig.layout.update(title_text="Time analysis", xaxis_rangeslider_visible=True)
#      11     st.plotly_chart(fig)
# ---> 12 plot_raw_meat_data()
#      13
#
# <ipython-input-20-ab2b83e2d040> in plot_raw_meat_data()
#       6 def plot_raw_meat_data():
#       7     fig = go.Figure()
# ----> 8     fig.add_trace(go.Scatter(x=data["Date"], y=date["Open"], name = "Stock open"))
#       9     fig.add_trace(go.Scatter(x=data["Date"], y=date["Close"], name = "Stock close"))
#      10     fig.layout.update(title_text="Time analysis", xaxis_rangeslider_visible=True)
#
# TypeError: 'type' object is not subscriptable

# %%
#forecasting
df_train = data[["Date", "Close"]]
df_train = df_train.rename(columns = {"Date": "ds", "Close": "y" })

m = Prophet()
m.fit(df_train)
future = m.make_future_dataframe(periods=period)
forecast = m.predict(future)

st.subheader("Raw meat forecast")
st.write(forecast.tail())
# Out:
# 2021-12-14 12:04:57.702 Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
#forecast plot
st.write("Hunt outcome")
fig1 = plot_plotly(m, forecast)
st.plotly_chart(fig1)

st.write("Hunt components")
fig2 = m.plot_components(forecast.tail())
